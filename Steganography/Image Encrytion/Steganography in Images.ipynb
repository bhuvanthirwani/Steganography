# %% [markdown]
# # Image Encryption

# %% [markdown]
# ### Image Input

# %%
import matplotlib.pyplot as plt,numpy as np,random
from numpy import zeros
#Enter the address of the image inside r""
#Enter a jpg image.
img=plt.imread(r"Image.jpg")

rows=img.shape[0]
col=img.shape[1]

plt.title("Original Image")
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Generating PRIVATE Key

# %%
#Here I had generated a key with the help og random values. You can skip this step and provide your own key below.
key=[]
import random
while len(key)!=256:
    j=random.randrange(0,256)
    if j not in key:
        key.append(j)
for i in range(256):
    print(key[i],end=" ")
# Out:
# 77 219 19 32 220 17 2 233 18 250 208 188 9 248 157 197 201 127 35 199 95 200 192 193 134 31 159 247 185 21 189 180 132 190 120 124 246 69 243 1 88 108 198 78 222 140 29 211 204 112 38 151 103 111 128 41 0 99 58 166 63 165 206 169 109 184 143 156 217 158 175 98 245 3 203 5 154 4 167 56 92 64 179 142 183 96 16 27 227 75 146 148 232 55 49 162 67 195 118 6 14 126 170 234 172 210 57 163 114 171 66 215 160 121 79 51 242 123 136 45 152 42 119 249 223 202 196 212 100 62 101 94 91 8 12 40 39 13 81 24 186 84 182 235 164 221 236 231 216 135 122 141 139 254 228 80 130 46 10 83 117 252 237 187 68 176 33 207 224 36 155 47 129 110 161 230 239 226 107 244 102 131 251 82 205 214 15 44 37 25 20 34 59 194 65 90 71 61 137 70 191 105 93 54 177 11 240 173 225 89 241 104 87 145 28 60 218 76 72 52 73 168 138 115 48 113 53 153 178 229 149 7 209 147 238 86 23 106 26 50 116 30 144 253 125 150 43 74 97 181 85 22 255 174 213 133

# %% [markdown]
# ### Encryption of Image

# %%
#You can enter your own key in form of a list of randomly arranged numbers from 0 to 255.
#key=[]

def encrypt_image(img, key, rows, col):
    img1=np.zeros((rows,col,3),dtype=int)
    for i in range(rows):
        for j in range(col):
            for k in range(3):
                img1[i][j][k]=key[img[i][j][k]]
    return img1

img1=encrypt_image(img,key,rows,col)
plt.title("Encrypted Image")
plt.imshow(img1)
plt.show()

# %% [markdown]
# # Lets Start Decryption

# %% [markdown]
# ### Enter PRIVATE Key

# %%
print("Enter Private Key: ")
key=list(map(int,input().split()))
# Out:
# Enter Private Key:
# 77 219 19 32 220 17 2 233 18 250 208 188 9 248 157 197 201 127 35 199 95 200 192 193 134 31 159 247 185 21 189 180 132 190 120 124 246 69 243 1 88 108 198 78 222 140 29 211 204 112 38 151 103 111 128 41 0 99 58 166 63 165 206 169 109 184 143 156 217 158 175 98 245 3 203 5 154 4 167 56 92 64 179 142 183 96 16 27 227 75 146 148 232 55 49 162 67 195 118 6 14 126 170 234 172 210 57 163 114 171 66 215 160 121 79 51 242 123 136 45 152 42 119 249 223 202 196 212 100 62 101 94 91 8 12 40 39 13 81 24 186 84 182 235 164 221 236 231 216 135 122 141 139 254 228 80 130 46 10 83 117 252 237 187 68 176 33 207 224 36 155 47 129 110 161 230 239 226 107 244 102 131 251 82 205 214 15 44 37 25 20 34 59 194 65 90 71 61 137 70 191 105 93 54 177 11 240 173 225 89 241 104 87 145 28 60 218 76 72 52 73 168 138 115 48 113 53 153 178 229 149 7 209 147 238 86 23 106 26 50 116 30 144 253 125 150 43 74 97 181 85 22 255 174 213 133

# %% [markdown]
# ### Decrypt Encrypted image

# %%
def decrypt_image(img,key, rows, col):
    img1=np.zeros((rows,col,3),dtype=int)
    for i in range(rows):
        for j in range(col):
            for k in range(3):
                img1[i][j][k]=key.index(img[i][j][k])
    return img1

img3=decrypt_image(img1,key,rows,col)
plt.title("Decrypted Image")
plt.imshow(img3)
plt.show()
